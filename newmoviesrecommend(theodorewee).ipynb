# %%
import pandas as pd
movies = pd.read_csv(r'C:\Users\user\Downloads\TMBD Top 10k movies.csv.csv')

# %%
movies.head(2)
# Out:
#       id                        title                 genre original_language  \
# 0    278     The Shawshank Redemption           Drama,Crime                en
# 1  19404  Dilwale Dulhania Le Jayenge  Comedy,Drama,Romance                hi
#
#                                             overview  popularity release_date  \
# 0  Framed in the 1940s for the double murder of h...      94.075   1994-09-23
# 1  Raj is a rich, carefree, happy-go-lucky second...      25.408   1995-10-19
#
#    vote_average  vote_count
# 0           8.7       21862
# 1           8.7        3731

# %%
movies.describe()
# Out:
#                   id    popularity  vote_average    vote_count
# count   10000.000000  10000.000000  10000.000000  10000.000000
# mean   161243.505000     34.697267      6.621150   1547.309400
# std    211422.046043    211.684175      0.766231   2648.295789
# min         5.000000      0.600000      4.600000    200.000000
# 25%     10127.750000      9.154750      6.100000    315.000000
# 50%     30002.500000     13.637500      6.600000    583.500000
# 75%    310133.500000     25.651250      7.200000   1460.000000
# max    934761.000000  10436.917000      8.700000  31917.000000

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 10000 non-null  int64
#  1   title              10000 non-null  object
#  2   genre              9997 non-null   object
#  3   original_language  10000 non-null  object
#  4   overview           9987 non-null   object
#  5   popularity         10000 non-null  float64
#  6   release_date       10000 non-null  object
#  7   vote_average       10000 non-null  float64
#  8   vote_count         10000 non-null  int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 703.3+ KB

# %%
movies.isnull().sum()
# Out:
# id                    0
# title                 0
# genre                 3
# original_language     0
# overview             13
# popularity            0
# release_date          0
# vote_average          0
# vote_count            0
# dtype: int64

# %%
movies.isnull().sum()
# Out:
# id                    0
# title                 0
# genre                 3
# original_language     0
# overview             13
# popularity            0
# release_date          0
# vote_average          0
# vote_count            0
# dtype: int64

# %%
movies.isnull().sum()
# Out:
# id                    0
# title                 0
# genre                 3
# original_language     0
# overview             13
# popularity            0
# release_date          0
# vote_average          0
# vote_count            0
# dtype: int64

# %%
movies.columns
# Out:
# Index(['id', 'title', 'genre', 'original_language', 'overview', 'popularity',
#        'release_date', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
movies.shape
# Out:
# (10000, 9)

# %%
movies.size
movies.dtypes
# Out:
# id                     int64
# title                 object
# genre                 object
# original_language     object
# overview              object
# popularity           float64
# release_date          object
# vote_average         float64
# vote_count             int64
# dtype: object

# %%
movies.size
# Out:
# 90000

# %%
movies[movies.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, title, genre, original_language, overview, popularity, release_date, vote_average, vote_count]
# Index: []

# %%
movies = movies[['id','title','overview','genre']]

# %%
movies
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                overview  \
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# ...

# %%
movies.head(5)
# Out:
#       id                        title  \
# 0    278     The Shawshank Redemption
# 1  19404  Dilwale Dulhania Le Jayenge
# 2    238                The Godfather
# 3    424             Schindler's List
# 4    240       The Godfather: Part II
#
#                                             overview                 genre
# 0  Framed in the 1940s for the double murder of h...           Drama,Crime
# 1  Raj is a rich, carefree, happy-go-lucky second...  Comedy,Drama,Romance
# 2  Spanning the years 1945 to 1955, a chronicle o...           Drama,Crime
# 3  The true story of how businessman Oskar Schind...     Drama,History,War
# 4  In the continuing saga of the Corleone crime f...           Drama,Crime

# %%
movies.columns
# Out:
# Index(['id', 'title', 'overview', 'genre'], dtype='object')

# %%
#content based recommendation system
movies['tags'] = movies['overview']+movies['genre']

# %%
movies
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                overview  \
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# ...

# %%
new_data = movies.drop(columns=['overview','genre'])

# %%
new_data
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                    tags
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# ...

# %%
new_data.info
# Out:
# <bound method DataFrame.info of           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                    tags
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# ...

# %%
new_data.columns
# Out:
# Index(['id', 'title', 'tags'], dtype='object')

# %%
new_data[new_data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, title, tags]
# Index: []

# %%
#bag of word, TFIDF(term frequency inverse document frequency-reflect importance of word)
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(max_features=10000, stop_words='english')

# %%
cv
# Out:
# CountVectorizer(max_features=10000, stop_words='english')

# %%
vector = cv.fit_transform(new_data['tags'].values.astype('U')).toarray()

# %%
vector.shape
# Out:
# (10000, 10000)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vector)

# %%
similarity
# Out:
# array([[1.        , 0.05634362, 0.12888482, ..., 0.07559289, 0.11065667,
#         0.06388766],
#        [0.05634362, 1.        , 0.07624929, ..., 0.        , 0.03636965,
#         0.        ],
#        [0.12888482, 0.07624929, 1.        , ..., 0.02273314, 0.06655583,
#         0.08645856],
#        ...,
#        [0.07559289, 0.        , 0.02273314, ..., 1.        , 0.03253   ,
#         0.02817181],
#        [0.11065667, 0.03636965, 0.06655583, ..., 0.03253   , 1.        ,
#         0.0412393 ],
#        [0.06388766, 0.        , 0.08645856, ..., 0.02817181, 0.0412393 ,
#         1.        ]])

# %%
new_data[new_data['title']=="The Godfather"].index[0]
# Out:
# 2

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      10000 non-null  int64
#  1   title   10000 non-null  object
#  2   tags    9985 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 234.5+ KB

# %%
list(enumerate(similarity[2]))
# Out:
# [(0, 0.12888481555661677),
#  (1, 0.07624928516630233),
#  (2, 1.0000000000000004),
#  (3, 0.03327791628198609),
#  (4, 0.48976229911514363),
#  (5, 0.038124642583151166),
#  (6, 0.1363988678940947),
#  (7, 0.04883862905055043),
#  (8, 0.0),
#  (9, 0.03179815003744467),
#  (10, 0.08645856265563523),
#  (11, 0.0),
#  (12, 0.12688648033134406),
#  (13, 0.10783277320343841),
#  (14, 0.0),
#  (15, 0.15739281264465077),
#  (16, 0.03327791628198609),
#  (17, 0.1829982843991256),
#  (18, 0.0),
#  (19, 0.0),
#  (20, 0.0650256088762355),
#  (21, 0.036986336072765455),
#  (22, 0.028819520885211745),
#  (23, 0.1829982843991256),
#  (24, 0.07397267214553091),
#  (25, 0.1617491598051576),
#  (26, 0.22191801643659276),
#  (27, 0.06819943394704735),
#  (28, 0.05981486045545792),
#  (29, 0.03112864031823452),
#  (30, 0.03251280443811775),
#  (31, 0.027842302319485226),
#  (32, 0.03251280443811775),
#  (33, 0.030499714066520935),
#  (34, 0.04706208053350117),
#  (35, 0.03251280443811775),
# ...

# %%
distance = sorted(list(enumerate(similarity[2])), reverse=True, key=lambda vector:vector[1])
for i in distance[0:5]:
    print(i)
# Out:
# (2, 1.0000000000000004)
# (4, 0.48976229911514363)
# (7419, 0.3521803625302496)
# (153, 0.3354968547317302)
# (2624, 0.3234983196103152)

# %%
distance = sorted(list(enumerate(similarity[2])), reverse=True, key=lambda vector:vector[1])

# %%
distance = sorted(list(enumerate(similarity[2])), reverse=True, key=lambda vector:vector[1])
for i in distance[0:5]:
    print(new_data.iloc[i[0]].title)
# Out:
# The Godfather
# The Godfather: Part II
# Blood Ties
# Joker
# Bomb City

# %%
def recommend(movies):
    index = new_data[new_data['title']==movies].index[0]
    distance = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda vector:vector[1])
    for i in distance[0:5]:
        print(new_data.iloc[i[0]].title)

# %%
recommend('Iron Man')
# Out:
# Iron Man
# Iron Man 3
# Guardians of the Galaxy Vol. 2
# Avengers: Age of Ultron
# Star Wars: Episode III - Revenge of the Sith

# %%
recommend('The Godfather')
# Out:
# The Godfather
# The Godfather: Part II
# Blood Ties
# Joker
# Bomb City

# %%
recommend('Avatar')
# Out:
# Avatar
# Krull
# Small Soldiers
# Predator
# Iron Man 3

# %%
recommend('Frozen')
# Out:
# Frozen
# Olaf's Frozen Adventure
# Frozen II
# Togo
# Spirit: Stallion of the Cimarron

# %%
recommend('Titanic')
# Out:
# Titanic
# The Legend of 1900
# Standing Tall
# Nowhere Boy
# The Boxer

# %%
recommend('Joker')
# Out:
# Joker
# Blood Ties
# The Big Heat
# Dead Man Down
# Chopper
